# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv('yes_bank.csv',sep='|',nrows=200000)

# %%
print(dataset)
# Out:
#         cust_id_token                     current_address3  \
# 0                   1                                  NaN
# 1                   2                          INJAMBAKKAM
# 2                   3                           ROODEPOORT
# 3                   4                                  NaN
# 4                   5                                  NaN
# 5                   6                     TARDEO CIRCLE PT
# 6                   7                              PRADESH
# 7                   8                                  NaN
# 8                   9                                  NaN
# 9                  10                    NEAR CENTURY MALL
# 10                 11            NEAR BRIDGE STONE COMPANY
# 11                 12                                  NaN
# 12                 13                                  NaN
# 13                 14           BANDRA E NR COLGATE GROUND
# 14                 15                                  NaN
# ...

# %%
dataset=dataset[dataset.current_address3!='add3']
print(dataset)
# Out:
#         cust_id_token                     current_address3  \
# 0                   1                                  NaN
# 1                   2                          INJAMBAKKAM
# 2                   3                           ROODEPOORT
# 3                   4                                  NaN
# 4                   5                                  NaN
# 5                   6                     TARDEO CIRCLE PT
# 6                   7                              PRADESH
# 7                   8                                  NaN
# 8                   9                                  NaN
# 9                  10                    NEAR CENTURY MALL
# 10                 11            NEAR BRIDGE STONE COMPANY
# 11                 12                                  NaN
# 12                 13                                  NaN
# 13                 14           BANDRA E NR COLGATE GROUND
# 14                 15                                  NaN
# ...

# %%
from mpl_toolkits.basemap import Basemap
fig=plt.figure(figsize=(12,9))
m=Basemap(projection='mill')
m.drawcoastlines()
m.drawcountries()
m.fillcontinents(lake_color='blue')
m.drawmapboundary(fill_color='#FFFFFF')
xpt,ypt=m(-74,40)
#m.bluemarble()
m.plot(xpt,ypt,'co',markersize=7)
plt.title('Basemap')
plt.show()

# %%
df=pd.DataFrame(dataset,columns=['permanent_city','permanent_state'])
cf=df
#print(df)
df=df.drop_duplicates()
print(df)
# Out:
#                             permanent_city    permanent_state
# 0                                  CHENNAI         TAMIL NADU
# 1                                   LONDON         MIDDLE SEX
# 2                                     PUNE        MAHARASHTRA
# 3                                   BARODA            GUJARAT
# 4                                    SIRSA            HARYANA
# 5                                   MUMBAI        MAHARASHTRA
# 6                                 ITANAGAR  ARUNACHAL PRADESH
# 7                             SAUDI ARABIA       SAUDI ARABIA
# 8                                GHAZIABAD      UTTAR PRADESH
# 9                                  KOLKATA        WEST BENGAL
# 10                               SONBHADRA      UTTAR PRADESH
# 11                               AMBERNATH        MAHARASHTRA
# 12                                   DAUSA          RAJASTHAN
# 14                                   THANE        MAHARASHTRA
# ...

# %%
worldcities=pd.read_csv('worldcities.csv')
print(worldcities)
# Out:
#                 city     city_ascii      lat       lng        country iso2  \
# 0          Malishevë      Malisheve  42.4822   20.7458         Kosovo   XK
# 1            Prizren        Prizren  42.2139   20.7397         Kosovo   XK
# 2        Zubin Potok    Zubin Potok  42.9144   20.6897         Kosovo   XK
# 3           Kamenicë       Kamenice  42.5781   21.5803         Kosovo   XK
# 4               Viti           Viti  42.3214   21.3583         Kosovo   XK
# 5           Shtërpcë       Shterpce  42.2394   21.0272         Kosovo   XK
# 6             Shtime         Shtime  42.4331   21.0397         Kosovo   XK
# 7           Vushtrri       Vushtrri  42.8231   20.9675         Kosovo   XK
# 8            Dragash        Dragash  42.0265   20.6533         Kosovo   XK
# 9           Podujevë       Podujeve  42.9111   21.1899         Kosovo   XK
# 10      Fushë Kosovë   Fushe Kosove  42.6639   21.0961         Kosovo   XK
# ...

# %%
regions=df

for i in range(0,len(regions)):
    #print(i)
    if(regions.iloc[i,1]=='GUJARAT'):
        regions.iloc[i,0]='AHMEDABAD'
    if(regions.iloc[i,1]=='TAMIL NADU'):
        regions.iloc[i,0]='CHENNAI'
    if(regions.iloc[i,1]=='BIHAR'):
        regions.iloc[i,0]='PATNA'
    if(regions.iloc[i,1]=='UTTAR PRADESH'):
        regions.iloc[i,0]='LUCKNOW'
    if(regions.iloc[i,1]=='TAMIL NADU'):
        regions.iloc[i,0]='CHENNAI'
    if(regions.iloc[i,1]=='MAHARASHTRA'):
        regions.iloc[i,0]='MUMBAI'
    if(regions.iloc[i,1]=='HARYANA'):
        regions.iloc[i,0]='GURGAON'
    if(regions.iloc[i,1]=='ASSAM'):
        regions.iloc[i,0]='GUWAHATI'
    if(regions.iloc[i,1]=='RAJASTHAN'):
        regions.iloc[i,0]='JAIPUR'
    if(regions.iloc[i,1]=='KERALA'):
        regions.iloc[i,0]='CHENNAI'
    if(regions.iloc[i,1]=='PUNJAB'):
        regions.iloc[i,0]='PATHANKOT'
    if(regions.iloc[i,1]=='WEST BENGAL'):
        regions.iloc[i,0]='KOLKATA'
    if(regions.iloc[i,1]=='ANDHRA PRADESH'):
        regions.iloc[i,0]='HYDERABAD'
    if(regions.iloc[i,1]=='KARNATAKA'):
        regions.iloc[i,0]='BANGALORE'
    if(regions.iloc[i,1]=='MADHYA PRADESH'):
        regions.iloc[i,0]='BHOPAL'
    if(regions.iloc[i,1]=='DAMAN AND DIU'):
        regions.iloc[i,0]='DIU'
    if(regions.iloc[i,1]=='KERALA'):
        regions.iloc[i,0]='KOCHI'
    if(regions.iloc[i,1]=='MIZORAM'):
        regions.iloc[i,0]='AIZAWL'
    if(regions.iloc[i,1]=='JHARKHAND'):
        regions.iloc[i,0]='RANCHI'
    if(regions.iloc[i,1]=='ODISHA'):
        regions.iloc[i,0]='BHUBANESHWAR'
    if(regions.iloc[i,1]=='SIKKIM'):
        regions.iloc[i,0]='GANGTOK'
    if(regions.iloc[i,1]=='ODISHA'):
        regions.iloc[i,0]='BHUBANESHWAR'
    if(regions.iloc[i,1]=='GOA'):
        regions.iloc[i,0]='PANAJI'
    if(regions.iloc[i,1]=='NAGALAND'):
        regions.iloc[i,0]='KOHIMA'
    if(regions.iloc[i,1]=='TRIPURA'):
        regions.iloc[i,0]='AGARTALA'
    if(regions.iloc[i,1]=='MANIPUR'):
        regions.iloc[i,0]='IMPHAL'
    if(regions.iloc[i,1]=='DELHI'):
        regions.iloc[i,0]='DELHI'
    if(regions.iloc[i,1]=='PONDICHERRY'):
        regions.iloc[i,0]='PONDICHERRY'
    if(regions.iloc[i,1]=='ANDAMAN AND NICOBAR ISLANDS'):
        regions.iloc[i,0]='PORT BLAIR'
    if(regions.iloc[i,1]=='LAKSHADWEEP'):
        regions.iloc[i,0]='KAVARATTI'
    if(regions.iloc[i,1]=='UTTARAKHAND'):
        regions.iloc[i,0]='DEHRA DUN'
    if(regions.iloc[i,1]=='JAMMU AND KASHMIR'):
        regions.iloc[i,0]='SRINAGAR'
    if(regions.iloc[i,1]=='SAUDI ARABIA'):
        regions.iloc[i,0]='RIYADH'
    if(regions.iloc[i,1]=='ONTARIO'):
        regions.iloc[i,0]='ONTARIO' 
    if(regions.iloc[i,1]=='KUWAIT'):
        regions.iloc[i,0]='KUWAIT'

regions=regions.drop_duplicates()
#print(regions)
regions.insert(2,"Lat",[0]*len(regions),True)
regions.insert(3,"Long",[0]*len(regions),True)
print(regions)
# Out:
# C:\Users\kunal\anaconda4\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\kunal\anaconda4\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kunal\anaconda4\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %%
for i in range(0,len(regions)):
    #print(i)
    for j in range(0,len(worldcities)):
        if(regions.iloc[i,0]==worldcities.iloc[j,1].upper()):
            regions.iloc[i,2]=worldcities.iloc[j,2]
            regions.iloc[i,3]=worldcities.iloc[j,3]
            break
print(regions)
# Out:
# C:\Users\kunal\anaconda4\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                         permanent_city          permanent_state      Lat  \
# 0                              CHENNAI               TAMIL NADU  13.0900
# 1                               LONDON               MIDDLE SEX  42.9700
# 2                               MUMBAI              MAHARASHTRA  19.0170
# 3                            AHMEDABAD                  GUJARAT  23.0301
# 4                              GURGAON                  HARYANA  28.4500
# 6                             ITANAGAR        ARUNACHAL PRADESH  27.1004
# 7                               RIYADH             SAUDI ARABIA  24.6408
# ...

# %%
regions=regions[regions.Lat!=0]
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800
# 4               GURGAON            HARYANA  28.4500   77.0200
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100
# 15                DUBAI              DUBAI  25.2300   55.2800
# 16               RANCHI          JHARKHAND  23.3700   85.3300
# 18             GUWAHATI              ASSAM  26.1600   91.7700
# 22             HARRISON         CALIFORNIA  44.2265  -88.3312
# ...

# %%
regions.insert(4,"Numcust",[0]*len(regions),True)
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800        0
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500        0
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570        0
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800        0
# 4               GURGAON            HARYANA  28.4500   77.0200        0
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166        0
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727        0
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150        0
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247        0
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100        0
# 15                DUBAI              DUBAI  25.2300   55.2800        0
# 16               RANCHI          JHARKHAND  23.3700   85.3300        0
# ...

# %%
for i in range(0,10):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800        0
# 16               RANCHI          JHARKHAND  23.3700   85.3300        0
# ...

# %%
for i in range(10,20):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(20,30):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(30,40):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(40,50):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(50,60):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(60,70):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(70,80):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(80,90):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(90,100):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(100,110):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(110,120):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(120,130):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(130,140):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(140,150):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(150,160):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(160,170):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(170,180):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(180,190):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(190,200):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(200,210):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(210,220):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(220,230):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(230,240):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(240,250):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(250,260):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(260,270):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(270,280):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(280,290):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(290,300):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(300,310):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(310,320):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(320,330):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(330,340):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(340,350):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
for i in range(350,360):
    for j in range(0,len(cf)):
        #print(j)
        if(regions.iloc[i,0]==cf.iloc[j,0] or regions.iloc[i,1]==cf.iloc[j,1]):
            regions.iloc[i,4]=regions.iloc[i,4]+1
print(regions)
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
regions
# Out:
#          permanent_city    permanent_state      Lat      Long  Numcust
# 0               CHENNAI         TAMIL NADU  13.0900   80.2800     9087
# 1                LONDON         MIDDLE SEX  42.9700  -81.2500       14
# 2                MUMBAI        MAHARASHTRA  19.0170   72.8570    15725
# 3             AHMEDABAD            GUJARAT  23.0301   72.5800     9641
# 4               GURGAON            HARYANA  28.4500   77.0200     6897
# 6              ITANAGAR  ARUNACHAL PRADESH  27.1004   93.6166       35
# 7                RIYADH       SAUDI ARABIA  24.6408   46.7727       56
# 8               LUCKNOW      UTTAR PRADESH  26.8550   80.9150     7234
# 9               KOLKATA        WEST BENGAL  22.4950   88.3247     5335
# 12               JAIPUR          RAJASTHAN  26.9211   75.8100     8092
# 15                DUBAI              DUBAI  25.2300   55.2800      117
# 16               RANCHI          JHARKHAND  23.3700   85.3300      577
# ...

# %%
from mpl_toolkits.basemap import Basemap,cm
fig=plt.figure(figsize=(15,12))
m=Basemap(projection='mill')
m.drawcoastlines()
m.drawcountries()
m.fillcontinents(color='grey',lake_color='aqua')
m.drawmapboundary(fill_color='aqua')

#print(regions.iloc[0,3])

for i in range(len(regions)):
    xpt,ypt=m(regions.iloc[i,3],regions.iloc[i,2])
    if(regions.iloc[i,4]>=1 and regions.iloc[i,4]<200):
        m.plot(xpt,ypt,'go',markersize=3)
    if(regions.iloc[i,4]>=200 and regions.iloc[i,4]<500):
        m.plot(xpt,ypt,'bo',markersize=3)
    if(regions.iloc[i,4]>=500 and regions.iloc[i,4]<1000):
        m.plot(xpt,ypt,'co',markersize=3)
    if(regions.iloc[i,4]>=1000 and regions.iloc[i,4]<3000):
        m.plot(xpt,ypt,'yo',markersize=3)
    if(regions.iloc[i,4]>=3000):
        m.plot(xpt,ypt,'ro',markersize=3)
    
        
plt.plot(5,5,'green',label='1 to 200 customers')  
plt.plot(5,5,'blue',label='200 to 500 customers') 
plt.plot(5,5,'coral',label='500 to 1000 customers') 
plt.plot(5,5,'yellow',label='1000 to 3000 customers') 
plt.plot(5,5,'red',label='More than 3000 customers') 
#print(regions.iloc[:,3].values)
#plt.pcolormesh(xs, ys, density, cmap="custom_map")
#clevs = [0,1,2.5,5,7.5,10,15,20,30,40,50,70,100,150,200,250,300,400,500,600,750]
#print(xpt)
#cbar = m.colorbar(cs,location='bottom',pad="5%")

#xpt,ypt=m(-74,40)
#m.bluemarble()
#m.plot(xpt,ypt,'co',markersize=7)
#xpt,ypt=m(-84,40)
#m.bluemarble()
#m.plot(xpt,ypt,'wo',markersize=7)
#xpt,ypt=m(75,32)
#m.plot(xpt,ypt,'ko',markersize=7)
#x=[0,22350169]
#y=[0,22350169]
#plt.plot(x,y)
plt.title('World Map Showing the Number of Yes Bank Customers Around the World Based on Permanent Address.')
plt.legend()
plt.show()
#print(density)
